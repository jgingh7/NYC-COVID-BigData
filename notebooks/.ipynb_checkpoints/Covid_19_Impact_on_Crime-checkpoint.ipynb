# %%
import pandas as pd
import numpy as np

df = pd.read_csv('NYPD_Hate_Crimes.csv',header=0)

# %%
dfnew = df[['Full Complaint ID','Complaint Year Number','Month Number','Bias Motive Description','Offense Category','Other Motive Description','Arrest Id']]

# %%
# sorting by Full Complaint ID
dfnew.sort_values("Full Complaint ID", inplace = True)
  
# dropping ALL duplicte values
dfnew.drop_duplicates(subset ="Full Complaint ID", keep = False, inplace = True)

# sorting by Arrest Id
dfnew.sort_values("Arrest Id", inplace = True)
  
# dropping ALL duplicte values but not NaN
dfnew=dfnew[dfnew['Arrest Id'].isnull() | ~dfnew[dfnew['Arrest Id'].notnull()].duplicated(subset='Arrest Id',keep='first')]

dfnew.style
# Out:
# <ipython-input-160-69796a751905>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew.sort_values("Full Complaint ID", inplace = True)
# <ipython-input-160-69796a751905>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew.drop_duplicates(subset ="Full Complaint ID", keep = False, inplace = True)
# <ipython-input-160-69796a751905>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew.sort_values("Arrest Id", inplace = True)
# <style  type="text/css" >
# </style><table id="T_2769c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Full Complaint ID</th>        <th class="col_heading level0 col1" >Complaint Year Number</th>        <th class="col_heading level0 col2" >Month Number</th>        <th class="col_heading level0 col3" >Bias Motive Description</th>        <th class="col_heading level0 col4" >Offense Category</th>        <th class="col_heading level0 col5" >Other Motive Description</th>        <th class="col_heading level0 col6" >Arrest Id</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2769c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2769c_row0_col0" class="data row0 col0" >201904600132799</td>
#                         <td id="T_2769c_row0_col1" class="data row0 col1" >2019</td>
#                         <td id="T_2769c_row0_col2" class="data row0 col2" >2</td>
#                         <td id="T_2769c_row0_col3" class="data row0 col3" >ANTI-MALE HOMOSEXUAL(GAY)</td>
#                         <td id="T_2769c_row0_col4" class="data row0 col4" >Sexual Orientation</td>
#                         <td id="T_2769c_row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_2769c_row0_col6" class="data row0 col6" >B19606200</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2769c_row1_col0" class="data row1 col0" >201904800157499</td>
#                         <td id="T_2769c_row1_col1" class="data row1 col1" >2019</td>
#                         <td id="T_2769c_row1_col2" class="data row1 col2" >3</td>
#                         <td id="T_2769c_row1_col3" class="data row1 col3" >ANTI-WHITE</td>
#                         <td id="T_2769c_row1_col4" class="data row1 col4" >Race/Color</td>
#                         <td id="T_2769c_row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_2769c_row1_col6" class="data row1 col6" >B19610772</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2769c_row2_col0" class="data row2 col0" >201904800154599</td>
#                         <td id="T_2769c_row2_col1" class="data row2 col1" >2019</td>
#                         <td id="T_2769c_row2_col2" class="data row2 col2" >3</td>
#                         <td id="T_2769c_row2_col3" class="data row2 col3" >ANTI-WHITE</td>
#                         <td id="T_2769c_row2_col4" class="data row2 col4" >Race/Color</td>
#                         <td id="T_2769c_row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_2769c_row2_col6" class="data row2 col6" >B19610788</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row3" class="row_heading level0 row3" >7</th>
#                         <td id="T_2769c_row3_col0" class="data row3 col0" >201904000639299</td>
#                         <td id="T_2769c_row3_col1" class="data row3 col1" >2019</td>
#                         <td id="T_2769c_row3_col2" class="data row3 col2" >6</td>
#                         <td id="T_2769c_row3_col3" class="data row3 col3" >ANTI-WHITE</td>
#                         <td id="T_2769c_row3_col4" class="data row3 col4" >Race/Color</td>
#                         <td id="T_2769c_row3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_2769c_row3_col6" class="data row3 col6" >B19625012</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row4" class="row_heading level0 row4" >8</th>
#                         <td id="T_2769c_row4_col0" class="data row4 col0" >201904900423199</td>
#                         <td id="T_2769c_row4_col1" class="data row4 col1" >2019</td>
#                         <td id="T_2769c_row4_col2" class="data row4 col2" >7</td>
#                         <td id="T_2769c_row4_col3" class="data row4 col3" >ANTI-HISPANIC</td>
#                         <td id="T_2769c_row4_col4" class="data row4 col4" >Ethnicity/National Origin/Ancestry</td>
#                         <td id="T_2769c_row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_2769c_row4_col6" class="data row4 col6" >B19630132</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row5" class="row_heading level0 row5" >9</th>
#                         <td id="T_2769c_row5_col0" class="data row5 col0" >201904700779599</td>
#                         <td id="T_2769c_row5_col1" class="data row5 col1" >2019</td>
#                         <td id="T_2769c_row5_col2" class="data row5 col2" >8</td>
#                         <td id="T_2769c_row5_col3" class="data row5 col3" >ANTI-TRANSGENDER</td>
#                         <td id="T_2769c_row5_col4" class="data row5 col4" >Gender</td>
#                         <td id="T_2769c_row5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_2769c_row5_col6" class="data row5 col6" >B19632323</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row6" class="row_heading level0 row6" >12</th>
#                         <td id="T_2769c_row6_col0" class="data row6 col0" >201907100753899</td>
#                         <td id="T_2769c_row6_col1" class="data row6 col1" >2019</td>
#                         <td id="T_2769c_row6_col2" class="data row6 col2" >12</td>
#                         <td id="T_2769c_row6_col3" class="data row6 col3" >ANTI-JEWISH</td>
#                         <td id="T_2769c_row6_col4" class="data row6 col4" >Religion/Religious Practice</td>
#                         <td id="T_2769c_row6_col5" class="data row6 col5" >nan</td>
#                         <td id="T_2769c_row6_col6" class="data row6 col6" >B19650852</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row7" class="row_heading level0 row7" >13</th>
#                         <td id="T_2769c_row7_col0" class="data row7 col0" >202004400142999</td>
#                         <td id="T_2769c_row7_col1" class="data row7 col1" >2020</td>
#                         <td id="T_2769c_row7_col2" class="data row7 col2" >2</td>
#                         <td id="T_2769c_row7_col3" class="data row7 col3" >ANTI-MALE HOMOSEXUAL(GAY)</td>
#                         <td id="T_2769c_row7_col4" class="data row7 col4" >Sexual Orientation</td>
#                         <td id="T_2769c_row7_col5" class="data row7 col5" >nan</td>
#                         <td id="T_2769c_row7_col6" class="data row7 col6" >B20604576</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row8" class="row_heading level0 row8" >17</th>
#                         <td id="T_2769c_row8_col0" class="data row8 col0" >202004900218899</td>
#                         <td id="T_2769c_row8_col1" class="data row8 col1" >2020</td>
#                         <td id="T_2769c_row8_col2" class="data row8 col2" >4</td>
#                         <td id="T_2769c_row8_col3" class="data row8 col3" >ANTI-JEWISH</td>
#                         <td id="T_2769c_row8_col4" class="data row8 col4" >Religion/Religious Practice</td>
#                         <td id="T_2769c_row8_col5" class="data row8 col5" >nan</td>
#                         <td id="T_2769c_row8_col6" class="data row8 col6" >B20612516</td>
#             </tr>
#             <tr>
#                         <th id="T_2769c_level0_row9" class="row_heading level0 row9" >20</th>
#                         <td id="T_2769c_row9_col0" class="data row9 col0" >202004000774499</td>
#                         <td id="T_2769c_row9_col1" class="data row9 col1" >2020</td>
#                         <td id="T_2769c_row9_col2" class="data row9 col2" >7</td>
#                         <td id="T_2769c_row9_col3" class="data row9 col3" >ANTI-ASIAN</td>
#                         <td id="T_2769c_row9_col4" class="data row9 col4" >Race/Color<

# %%
res = dfnew.groupby('Complaint Year Number').size()
print(res)
# Out:
# Complaint Year Number
# 2019    404
# 2020    247
# dtype: int64

# %%
dfByYear = pd.DataFrame(res)
dfByYear.plot.bar()
plt.show()

# %%
groupedTable = dfnew.groupby(['Complaint Year Number', 'Bias Motive Description']).size().to_frame('size')
print(groupedTable)
# Out:
#                                                          size
# Complaint Year Number Bias Motive Description
# 2019                  ANTI-ARAB                             5
#                       ANTI-ASIAN                            1
#                       ANTI-BLACK                           34
#                       ANTI-BUDDHIST                         2
#                       ANTI-CATHOLIC                         6
#                       ANTI-FEMALE HOMOSEXUAL(GAY)           3
#                       ANTI-HISPANIC                         8
#                       ANTI-ISLAMIC(MUSLIM)                 10
#                       ANTI-JEHOVAS WITNESS                  1
#                       ANTI-JEWISH                         235
#                       ANTI-LGBT(MIXED GROUP)                7
#                       ANTI-MALE HOMOSEXUAL(GAY)            36
#                       ANTI-MULTI RACIAL GROUPS              1
#                       ANTI-OTHER ETHNICITY                  9
#                       ANTI-OTHER RELIGION                   2
#                       ANTI-PHYSICAL DISABILITY              1
#                       ANTI-TRANSGENDER                     13
#                       ANTI-WHITE                           27
# 2020                  50 YEARS OLD OR MORE                  1
#                       ANTI-ARAB                             1
#                       ANTI-ASIAN                           26
#                       ANTI-BLACK                           39
#                       ANTI-CATHOLIC                         9
#                       ANTI-FEMALE                           2
#                       ANTI-FEMALE HOMOSEXUAL(GAY)           3
#                       ANTI-GENDER NON CONFORMING            2
#                       ANTI-HINDU                            2
#                       ANTI-HISPANIC                         1
#                       ANTI-ISLAMIC(MUSLIM)                  3
#                       ANTI-JEWISH                         110
#                       ANTI-LGBT(MIXED GROUP)                1
#                       ANTI-MALE HOMOSEXUAL(GAY)            23
#                       ANTI-MULTI RACIAL GROUPS              2
#                       ANTI-OTHER ETHNICITY                  5
#                       ANTI-RELIGIOUS PRACTICE GENERALLY     2
#                       ANTI-TRANSGENDER                      4
#                       ANTI-WHITE                           10
#                       OTHER                                 1

# %%
plot = pd.crosstab(dfnew['Bias Motive Description'],dfnew['Complaint Year Number']).plot(kind='bar', width=0.6, figsize=(30,20), fontsize=20)
plot.legend(loc=2,fontsize=20)
plt.show()
